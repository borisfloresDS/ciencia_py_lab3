# %% [markdown]
# # Laboratorio: Análisis de Datos con Python

# %% [markdown]
# ## Parte 1

# %% [markdown]
# ### 1) ¿Cuál es el tamaño en bytes de un array de 1000 elementos de tipo booleano

# %%
import numpy as np
import sys

# %%
array_buleano = [True] * 1000

tamaño_bytes = print(sys.getsizeof(array_buleano))
# Out:
# 8056

# %% [markdown]
# El tamaño de bytes de un array de 1000 elementos tipo booleano es de 8056 bytes

# %% [markdown]
# un elemento buleano de 1000 es de 8056 byte

# %% [markdown]
# ### 2). Cree un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla.

# %%
pares = np.arange(100, 0, -2)

# %%
pares[-10:]
# Out:
# array([20, 18, 16, 14, 12, 10,  8,  6,  4,  2])

# %% [markdown]
# ### 3) Dado el array
#
# 2 4 5 6
# 0 3 7 4
# 8 8 5 2
# 1 5 6 1

# %%
array3 = np.array([[2, 4, 5, 6],[0, 3, 7, 4],[8, 8, 5, 2],[1, 5, 6, 1]])

# %% [markdown]
# Seleccione con una instrucción el subarray de elementos

# %%
#seleccionado un subarray de elementos
array3[1]
# Out:
# array([0, 3, 7, 4])

# %%
# así se selecciona el subarray de elementos
print(array3[[0, 2]][:, [0, 2]])
# Out:
# [[2 5]
#  [8 5]]

# %% [markdown]
# ### 4) Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
a = np.array([1,4,2,7])
b = np.array([1,3,2,9])

# %%
dif = a - b
media_art = np.mean(dif)

# %%
# Esta es la media metrica de la diferencia de a - b
media_art
# Out:
# -0.25

# %% [markdown]
# ### 5) Tengo valores de cordenadas (x, y) en las columnas del array

# %%
array5 = np.array([[1.33,4.5],[30.0,10.7],[70.2,0.5]])

# %%
newcord = [37.1,-3.6]

# %%
# se agrega el array (37.1, -3.6)
array5= np.append(array5,[newcord], axis=0)

# %%
array5
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ],
#        [37.1 , -3.6 ]])

# %% [markdown]
# ### 6) Copie el array del ejercicio anterior. Traspóngalo (. Agregue ahora dos nuevos pares de coordenadas: (10.8, 3.0) y (35.8, 12.0).

# %%
array6 = np.transpose(array5)

# %%
newcord1 = np.array([[10.8], [3.0]])
newcord2 = np.array([[35.8], [12.0]])

# %%
#aquí se agreaga el array (10.8,3.0)
array6_2 = np.hstack((array6,newcord1))

# %%
#aquí se agrega el array (35.8,12.0)
array6_2 = np.hstack((array6_2,newcord2))

# %%
array6_2
# Out:
# array([[ 1.33, 30.  , 70.2 , 37.1 , 10.8 , 35.8 ],
#        [ 4.5 , 10.7 ,  0.5 , -3.6 ,  3.  , 12.  ]])

# %% [markdown]
# ## Parte 2: Exploración y Minería de Datos:

# %%
import pandas as pd

# %%
df = pd.read_csv('NucleosPoblacion.csv')

# %%
df.head()
# Out:
#    FID  OBJECTID     Texto  Poblacion  CodMun Municipio  CodProvin  \
# 0    0         1   Agüimes    29431.0   35002   Agüimes         35
# 1    1         2   Antigua    10458.0   35003   Antigua         35
# 2    2         3  Arrecife    58156.0   35004  Arrecife         35
# 3    3         4    Arucas    36745.0   35006    Arucas         35
# 4    4         5    Gáldar    24473.0   35009    Gáldar         35
#
#     Provincia          X          Y
# 0  Las Palmas -15.446012  27.900542
# 1  Las Palmas -14.013301  28.418966
# 2  Las Palmas -13.551451  28.960649
# 3  Las Palmas -15.521512  28.117496
# 4  Las Palmas -15.654111  28.143873

# %%
mas_de_100000 = df[df['Poblacion'] > 100000]

# %%
mas_de_100000['Municipio'].nunique()
# Out:
# 62

# %% [markdown]
# Hay 62 municipios con mas de 100000 habitantes

# %% [markdown]
# ### 2) Realice una gráfica de barras sobre la polbación de cada ciudad, ordenela de menor a mayo y responda:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ord_df = df.sort_values(by='Poblacion')

# %%
#polt de manera ciudad/municipio de menor a mayor poblacion
plt.figure(figsize=(10, 6))
sns.barplot(data = ord_df, x = 'Municipio', y = 'Poblacion')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### a. ¿Cuál es la segunda ciudad más poblada?

# %%
ord_df.tail()
# Out:
#      FID  OBJECTID      Texto  Poblacion  CodMun  Municipio  CodProvin  \
# 591  591       592   Zaragoza   675121.0   50297   Zaragoza         50
# 492  492       493    Sevilla   704198.0   41091    Sevilla         41
# 561  561       562   Valencia   809267.0   46250   Valencia         46
# 623  623       624  Barcelona  1619337.0    8019  Barcelona          8
# 355  355       356     Madrid  3273049.0   28079     Madrid         28
#
#              Provincia         X          Y
# 591           Zaragoza -0.879287  41.656457
# 492            Sevilla -5.992514  37.386205
# 561  València/Valencia -0.375657  39.475344
# 623          Barcelona  2.176349  41.384247
# 355             Madrid -3.703797  40.416630

# %% [markdown]
# La segunda ciudad con mas poblacion es Barcelona

# %% [markdown]
# ### b. ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas

# %%
posicion_granada = ord_df[ord_df['Municipio'] == 'Granada'].index[0]

# %%
print(posicion_granada)
print('La posición de granada es 273')
# Out:
# 272

# %% [markdown]
# ### 3) ¿Cuántos municipios de Extremadura tienen más de 5000 habitantes?.

# %%
provs = df['Provincia'].unique()
print(provs)
# Out:
# ['Las Palmas' 'Santa Cruz de Tenerife' 'Badajoz' 'Cáceres' 'Cádiz'
#  'A Coruña' 'Huelva' 'León' 'Lugo' 'Ourense' 'Asturias' 'Pontevedra'
#  'Salamanca' 'Sevilla' 'Albacete' 'Alacant/Alicante' 'Álava' 'Almería'
#  'Ávila' 'Burgos' 'Castelló/Castellón' 'Ciudad Real' 'Córdoba' 'Cuenca'
#  'Granada' 'Guadalajara' 'Guipúzcoa' 'Huesca' 'Jaén' 'La Rioja' 'Madrid'
#  'Málaga' 'Murcia' 'Navarra' 'Palencia' 'Cantabria' 'Segovia' 'Soria'
#  'Teruel' 'Toledo' 'València/Valencia' 'Valladolid' 'Vizcaya' 'Zamora'
#  'Zaragoza' 'Ceuta' 'Illes Balears' 'Barcelona' 'Girona' 'Lleida'
#  'Tarragona' 'Melilla']

# %%
extremadura = df[(df['Provincia'] == 'Badajoz') | (df['Provincia'] == 'Cáceres') ]

# %%
extremadura_5000_p = extremadura[extremadura['Poblacion'] > 5000]

# %%
len(extremadura_5000_p['Municipio'].unique())
# Out:
# 14

# %% [markdown]
# Hay 14 municipios en extremadura que tienen más de 5000 habitantes.

# %% [markdown]
# ### 4) ¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que pertenece y su población.

# %%
dfnorte = df.sort_values(by = 'Y',ascending=False)

# %%
dfnorte.head()
# Out:
#      FID  OBJECTID           Texto  Poblacion  CodMun   Municipio  CodProvin  \
# 104  104       105         Viveiro    16211.0   27066     Viveiro         27
# 447  447       448  Lluanco/Luanco    10788.0   33025       Gozón         33
# 443  443       444          Candás    11000.0   33014     Carreño         33
# 444  444       445  Piedrasblancas    22832.0   33016  Castrillón         33
# 442  442       443          Avilés    84202.0   33004      Avilés         33
#
#     Provincia         X          Y
# 104      Lugo -7.588768  43.625578
# 447  Asturias -5.792773  43.614030
# 443  Asturias -5.767181  43.590199
# 444  Asturias -5.973899  43.559984
# 442  Asturias -5.924790  43.558577

# %% [markdown]
# Viveiro es el municipio mas al norte

# %% [markdown]
# ### 5) Obtenga la media, mediana, desviación estándar, valor máximo y valor mínimo de la población de los municipios de la provincia de Granada.

# %%
granada_prob = df[df['Provincia'] == 'Granada']

# %%
granada_prob
# Out:
#      FID  OBJECTID                 Texto  Poblacion  CodMun  \
# 266  266       267              Albolote    17637.0   18003
# 267  267       268             Almuñécar    27703.0   18017
# 268  268       269               Armilla    21895.0   18021
# 269  269       270                Atarfe    15945.0   18022
# 270  270       271                  Baza    21982.0   18023
# 271  271       272  Churriana de la Vega    12448.0   18062
# 272  272       273               Granada   239154.0   18087
# 273  273       274                Guadix    20407.0   18089
# 274  274       275           Huétor Vega    11551.0   18101
# 275  275       276                Illora    10386.0   18102
# 276  276       277                  Loja    21688.0   18122
# 277  277       278              Maracena    21097.0   18127
# 278  278       279                Motril    60884.0   18140
# 279  279       280              Ogíjares    13255.0   18145
# 280  280       281              Peligros    11000.0   18153
# ...

# %%
granada_prob['Poblacion'].describe()
# Out:
# count        20.000000
# mean      30217.850000
# std       50355.491715
# min       10386.000000
# 25%       13146.500000
# 50%       17526.000000
# 75%       21739.750000
# max      239154.000000
# Name: Poblacion, dtype: float64

# %% [markdown]
# Valores descriptivos de la provincia de Granada
#
# Media                   30,217.85
# Mediana                 17,526
# Desviación estandar     50,355.49
# Valor máximo            239,154
# Valor mínimo            10,386

# %% [markdown]
# ### 6) Realice un histograma con la población de los Municipios para cada una de las provincias.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for i in df.Provincia.unique():
    sns.histplot(data=df, x = df[df['Provincia'] == i]['Poblacion'] )
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# ### 7) Seleccione al azar cincuenta municipios diferentes de entre los diponibles en el archivo. Asegúrese de que no se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?

# %%
ale_50 = df.sample(n = 50, replace = False)

# %%
ale_50['Poblacion'].describe()
# Out:
# count        50.000000
# mean      37806.340000
# std       59494.221813
# min       10303.000000
# 25%       14867.500000
# 50%       20581.000000
# 75%       30179.750000
# max      334418.000000
# Name: Poblacion, dtype: float64

# %% [markdown]
# El promedio es 37806.34 la desviasion standard es de 59494.221813

# %% [markdown]
# ### 8) Determine los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en todos ellos y Madrid. No considere a Madrid en el análisis ya que la distancia sería cero

# %%
Madrid = df[df['Municipio'] == 'Madrid']

# %%
Madrid
# Out:
#      FID  OBJECTID   Texto  Poblacion  CodMun Municipio  CodProvin Provincia  \
# 355  355       356  Madrid  3273049.0   28079    Madrid         28    Madrid
#
#             X         Y
# 355 -3.703797  40.41663

# %%
madrid_cords = [-3.703797, 40.41663]

# %%
from geopy.distance import geodesic

# %%
df['distancia_a_madrid'] = df.apply(lambda row: geodesic((row['X'], row['Y']), madrid_cords).kilometers, axis=1)

# %%
df_sin_madrid = df[df['Provincia'] != 'Madrid']

# %%
mun_cercano = df_sin_madrid.loc[df_sin_madrid['distancia_a_madrid'].idxmin()]['Provincia']

# %%
mun_lejano = df_sin_madrid.loc[df_sin_madrid['distancia_a_madrid'].idxmax()]['Provincia']

# %%
mun_cercano
# Out:
# 'Toledo'

# %%
mun_lejano
# Out:
# 'Santa Cruz de Tenerife'

# %% [markdown]
# La provincia más cercana es Toledo y la más lejana es Santa Cruz de Tenerife
